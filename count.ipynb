# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("실시간 전기차 충전소 상태정보.csv", encoding='cp949')
df
# Out:
#         Unnamed: 0          statNm    statId  chgerId  chgerType  \
# 0                0        홈플러스 영도점  ME000046        1          1
# 1                1         이마트 문현점  ME000048        1          3
# 2                2         이마트 금정점  ME000052        1          1
# 3                3      홈플러스 아시아드점  ME000055        1          3
# 4                4         이마트 연제점  ME000056        1          3
# ...            ...             ...       ...      ...        ...
# 251888      251900  부산교통공사 다대포해수욕장  TDL00002        1          5
# 251889      251901  부산교통공사 다대포해수욕장  TDL00002        2          5
# 251890      251902  부산교통공사 다대포해수욕장  TDL00002        3          5
# 251891      251903         부산은행 본점  TDL79002        1          2
# 251892      251904         부산은행 본점  TDL79002        2          2
#
#                            addr         location        lat         lng  \
# 0          부산광역시 영도구 대교로14번길 57              NaN  35.095906  129.044240
# ...

# %%
df.drop(columns=df.columns[0], inplace=True)

# %%
df
# Out:
#                 statNm    statId  chgerId  chgerType                     addr  \
# 0             홈플러스 영도점  ME000046        1          1     부산광역시 영도구 대교로14번길 57
# 1              이마트 문현점  ME000048        1          3     부산광역시 남구 전포대로91번길 47
# 2              이마트 금정점  ME000052        1          1  부산광역시 금정구 중앙대로1841번길 24
# 3           홈플러스 아시아드점  ME000055        1          3       부산광역시 연제구 종합운동장로 7
# 4              이마트 연제점  ME000056        1          3         부산광역시 연제구 연수로 89
# ...                ...       ...      ...        ...                      ...
# 251888  부산교통공사 다대포해수욕장  TDL00002        1          5      부산광역시 사하구 다대로 지하692
# 251889  부산교통공사 다대포해수욕장  TDL00002        2          5      부산광역시 사하구 다대로 지하692
# 251890  부산교통공사 다대포해수욕장  TDL00002        3          5      부산광역시 사하구 다대로 지하692
# 251891         부산은행 본점  TDL79002        1          2        부산광역시 남구 문현금융로 30
# 251892         부산은행 본점  TDL79002        2          2        부산광역시 남구 문현금융로 30
#
# ...
